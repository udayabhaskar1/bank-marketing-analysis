# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn

# %%
df = pd.read_csv('winequality-white.csv').dropna()
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
df.quality.value_counts()
# Out:
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: quality, dtype: int64

# %%
#For this first round, we attempt to do balancing

plt.figure()

sns.countplot('quality', data=df)

plt.title('raw')

plt.show()

# %%
df.quality.value_counts()
# Out:
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: quality, dtype: int64

# %%
#From graph, qualities 3 and 9 are too small. Therefore we do a mapping to convert them for dropping

dict_quality= {
    4: 4,
    5: 5,
    6: 6,
    7: 7,
    8: 8
}

df['quality'] = df['quality'].map(dict_quality)

#drop NaN columns
df = df.dropna()

df.quality.value_counts()
# Out:
# 6.0    2198
# 5.0    1457
# 7.0     880
# 8.0     175
# 4.0     163
# Name: quality, dtype: int64

# %%
# Shuffle the Dataset.
shuffled_df = df.sample(frac=1,random_state=4)

# Put all the minority class in a separate dataset.
q4_df = shuffled_df.loc[shuffled_df['quality'] == 4]

#Randomly select ? observations from the majority classes
q5_df = shuffled_df.loc[shuffled_df['quality'] == 5].sample(n = 163,random_state=42)

q6_df = shuffled_df.loc[shuffled_df['quality'] == 6].sample(n = 163,random_state=42)

q7_df = shuffled_df.loc[shuffled_df['quality'] == 7].sample(n = 163,random_state=42)

q8_df = shuffled_df.loc[shuffled_df['quality'] == 8].sample(n = 163,random_state=42)


# Concatenate both dataframes again
normalized_df = pd.concat([q4_df, q5_df, q6_df, q7_df, q8_df])

plt.figure()

sns.countplot('quality', data=normalized_df)

plt.title('balanced')

plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)

cax = ax1.imshow(normalized_df.corr(), interpolation="nearest")
ax1.grid(True)
plt.title('Correlation ')
labels=['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','quality']
ax1.set_xticklabels(labels,fontsize=6)
ax1.set_yticklabels(labels,fontsize=6)
# Add colorbar, make sure to specify tick locations to match desired ticklabels
fig.colorbar(cax, ticks=[-0.4,0,.4,.6,.8,.9,1])
plt.show()

# %%
normalized_df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.016584     0.329899
# volatile acidity           0.016584          1.000000    -0.224522
# citric acid                0.329899         -0.224522     1.000000
# residual sugar             0.056514         -0.030362     0.098169
# chlorides                  0.060271          0.120079    -0.013620
# free sulfur dioxide       -0.050574         -0.187926     0.085717
# total sulfur dioxide       0.089945         -0.008338     0.132832
# density                    0.290890         -0.017716     0.123602
# pH                        -0.452254         -0.020118    -0.142096
# sulphates                 -0.034397         -0.091873     0.080407
# alcohol                   -0.178733          0.075972    -0.007040
# quality                   -0.149701         -0.270637     0.055588
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.056514   0.060271            -0.050574
# volatile acidity           -0.030362   0.120079            -0.187926
# citric acid                 0.098169  -0.013620             0.085717
# residual sugar              1.000000   0.165737             0.307634
# chlorides                   0.165737   1.000000             0.006899
# free sulfur dioxide         0.307634   0.006899             1.000000
# total sulfur dioxide        0.410608   0.249668             0.609156
# density                     0.800518   0.336599             0.253535
# pH                         -0.202572  -0.095332             0.009701
# sulphates                  -0.044165   0.049257             0.159906
# alcohol                    -0.447238  -0.387237            -0.174681
# quality                    -0.007361  -0.252224             0.193370
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                     0.089945  0.290890 -0.452254  -0.034397
# volatile acidity                 -0.008338 -0.017716 -0.020118  -0.091873
# citric acid                       0.132832  0.123602 -0.142096   0.080407
# residual sugar                    0.410608  0.800518 -0.202572  -0.044165
# chlorides                         0.249668  0.336599 -0.095332   0.049257
# free sulfur dioxide               0.609156  0.253535  0.009701   0.159906
# total sulfur dioxide              1.000000  0.547447  0.029441   0.157182
# density                           0.547447  1.000000 -0.094401   0.065005
# pH                                0.029441 -0.094401  1.000000   0.198060
# sulphates                         0.157182  0.065005  0.198060   1.000000
# alcohol                          -0.467077 -0.821279  0.109663  -0.021512
# quality                          -0.091645 -0.320873  0.093974   0.028819
#
#                        alcohol   quality
# fixed acidity        -0.178733 -0.149701
# volatile acidity      0.075972 -0.270637
# citric acid          -0.007040  0.055588
# residual sugar       -0.447238 -0.007361
# chlorides            -0.387237 -0.252224
# free sulfur dioxide  -0.174681  0.193370
# total sulfur dioxide -0.467077 -0.091645
# density              -0.821279 -0.320873
# pH                    0.109663  0.093974
# sulphates            -0.021512  0.028819
# alcohol               1.000000  0.484688
# quality               0.484688  1.000000

# %% [markdown]
# # PCA

# %%
from sklearn.preprocessing import StandardScaler
#Separating out the features
features = ['volatile acidity','chlorides','density','alcohol']

#choose all features
# features = ['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol']
# Separating out the features
x_pca = normalized_df.loc[:, features].values
print(x_pca.shape)
#Separating out the target
y_pca = normalized_df.loc[:,['quality']].values
#standardizing the features
x_afterscaled = StandardScaler().fit_transform(x_pca)
# Out:
# (815, 4)

# %%
x_afterscaled.shape
# Out:
# (815, 4)

# %%
pd.DataFrame(data=x_afterscaled, columns=features).head()
# Out:
#    volatile acidity  chlorides   density   alcohol
# 0         -0.432027   0.081984  0.096840 -0.473858
# 1         -0.023793   4.760617 -0.337455 -0.627271
# 2          1.609143  -0.064224  0.497729 -0.013616
# 3         -0.268733   0.081984  1.479906 -1.394341
# 4         -0.105440  -0.112959  1.433135 -0.473858

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)
principalComponents = pca.fit_transform(x_afterscaled)
principaldf = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2'])

principaldf.head()
# Out:
#    principal component 1  principal component 2
# 0               0.404889              -0.440023
# 1               2.247238               1.676008
# 2               0.283079               1.396056
# 3               1.869809              -0.555563
# 4               1.162382              -0.345863

# %%
normalized_df['quality'].value_counts()
# Out:
# 8.0    163
# 7.0    163
# 6.0    163
# 5.0    163
# 4.0    163
# Name: quality, dtype: int64

# %%
print(principaldf.shape)
print(normalized_df['quality'].shape)

#change into numpy array
combined_arr = np.concatenate((principaldf.values,normalized_df[['quality']]), axis=1 )

#change back into dataframe
finalDf = pd.DataFrame(combined_arr, columns=['principal component 1','principal component 2','quality'])


print(finalDf.shape)
finalDf.head()
# Out:
# (815, 2)
# (815,)
# (815, 3)
#    principal component 1  principal component 2  quality
# 0               0.404889              -0.440023      4.0
# 1               2.247238               1.676008      4.0
# 2               0.283079               1.396056      4.0
# 3               1.869809              -0.555563      4.0
# 4               1.162382              -0.345863      4.0

# %%
fig = plt.figure(figsize = (16,8))
ax1 = fig.add_subplot(1,2,1) 
ax1.set_xlabel('Principal Component 1', fontsize = 15)
ax1.set_ylabel('Principal Component 2', fontsize = 15)
ax1.set_title('2 Component PCA', fontsize = 20)

targets = [4.0,5.0,6.0,7.0,8.0]
colors = ['red','yellow','green','orange','blue']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['quality'] == target
    ax1.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 50)
ax1.legend(targets)
ax1.grid()

# %%
print(pca.explained_variance_ratio_)

print(pca.explained_variance_ratio_.sum())
# Out:
# [0.51675638 0.26543826]
# 0.7821946429973408

# %% [markdown]
# That means this data is not really giving a good accuracy score when we use classification techniques
# Can justify when trying to use classification technique and see what the accuracy score is.
# Accuracy score should not be that high

# %% [markdown]
# # DBSCAN

# %%
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

#Separating out the features
features = ['density','alcohol']
x_dbscan = normalized_df.loc[:, features].values
#Separating out the target
y_pca = normalized_df.loc[:,['quality']].values
#standardizing the features
x_std = StandardScaler().fit_transform(x_dbscan)


# cluster the data
dbscan = DBSCAN(eps=0.123, min_samples = 2)
clusters = dbscan.fit_predict(x_std)

# plot the cluster assignments
print(x_std[:,0])
print(x_std[:,1])
plt.scatter(x_std[:, 0], x_std[:, 1], c=clusters)
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")

plt.show()
# Out:
# [ 9.68403977e-02 -3.37455481e-01  4.97728901e-01  1.47990573e+00
#   1.43313541e+00 -4.37677607e-01 -2.37233355e-01  1.44315762e+00
#   4.30914151e-01 -1.45994329e+00 -3.37455481e-01  4.84365951e-01
#  -8.18521685e-01  1.56008344e+00 -1.10285329e-01  1.55340196e+00
#   3.00256471e-02  1.33291328e+00 -1.17263986e+00  1.63655148e-01
#  -5.71307108e-01  3.00256471e-02 -2.37233355e-01 -9.65514136e-01
#   4.37595626e-01 -1.43692704e-01 -3.38172817e-03  1.56676491e+00
#  -7.88455047e-01  1.64694261e+00  9.68403977e-02 -5.54603420e-01
#  -8.21862423e-01 -4.57722032e-01 -1.97144505e-01 -9.72195612e-01
#   6.31358402e-01 -1.17263986e+00 -7.01964787e-02 -3.67891035e-02
#  -2.23870405e-01 -1.33967674e+00  6.98173153e-01  3.64099400e-01
#   2.30469899e-01 -3.44136956e-01  2.97284649e-01  1.39972803e+00
#   2.23491242e+00  4.77684476e-01  3.30692025e-01  4.64321526e-01
#   1.16587641e+00  1.39972803e+00 -9.25425286e-01  8.31802654e-01
#   1.29950591e+00  1.63357966e+00  6.17995452e-01  8.65210029e-01
#   1.29950591e+00  9.68403977e-02 -6.04714483e-01 -4.17633182e-01
#  -9.85558562e-01  1.13544085e-01  1.34293550e+00 -3.87566544e-01
#  -3.04048106e-01  4.87706689e-01  1.16587641e+00  9.98839530e-01
#   6.17995452e-01 -1.26283978e+00 -6.38121859e-01  6.31358402e-01
#  -1.57055654e-01  1.55340196e+00  6.64048441e-03 -8.21862423e-01
#  -7.98477260e-01  1.41643172e+00  1.16587641e+00  1.90083866e+00
#   2.97284649e-01  1.03224691e+00  8.98617405e-01 -9.02409039e-02
#  -3.30774006e-01  4.97728901e-01  1.63655148e-01  2.06787554e+00
#   5.97951027e-01  4.64321526e-01  8.31802654e-01 -1.10582511e+00
#   1.30247773e-01 -1.11918806e+00  8.31802654e-01  8.61869292e-01
#  -9.02409039e-02 -2.03825980e-01  4.37595626e-01  2.33810636e-01
#   2.30469899e-01  2.70558749e-01 -3.34483659e-02  4.27573413e-01
#  -7.58388410e-01  6.34330224e-02 -7.71751360e-01  2.63877274e-01
#   5.91269552e-01  1.53335754e+00 -3.01076284e-02 -3.34114744e-01
#  -3.70862856e-01 -9.12062336e-01  2.30469899e-01  1.13544085e-01
#  -5.04492357e-01  1.73380179e+00 -5.71307108e-01  1.16587641e+00
#   2.30469899e-01  9.68403977e-02  2.97284649e-01  5.91269552e-01
#  -9.12062336e-01 -2.37233355e-01  1.63655148e-01  4.84365951e-01
#   9.68403977e-02  5.31136276e-01 -2.77322206e-01  1.53335754e+00
#   7.71669378e-01  4.74343738e-01 -1.03901036e+00 -2.37233355e-01
#  -1.04569184e+00 -4.71084982e-01 -7.01964787e-02  7.24899053e-01
#  -9.05380861e-01  5.64543652e-01 -5.91351533e-01 -2.37233355e-01
#  -1.70418605e-01  9.32024780e-01  9.65432155e-01 -1.13255101e+00
#  -1.70418605e-01  5.51180702e-01  1.03224691e+00 -4.37677607e-01
#   7.64987903e-01 -4.84447932e-01 -3.34114744e-01  1.53335754e+00
#  -1.17263986e+00  2.90603174e-01 -1.50671362e+00 -7.28321772e-01
#  -1.16966804e-01  8.58528554e-01  3.64099400e-01  2.80580962e-01
#  -4.34705785e-02 -5.71307108e-01 -3.67891035e-02  2.43535667e+00
#   1.80061654e+00  1.53669827e+00 -4.04270232e-01  1.96765341e+00
#  -7.71751360e-01  1.16587641e+00  2.06787554e+00 -3.04048106e-01
#   3.00256471e-02 -1.03603854e-01  1.70039441e+00 -3.67891035e-02
#   1.84738686e+00 -2.23870405e-01  3.67071222e-02  1.33625402e+00
#   2.13469029e+00 -6.38121859e-01  6.34330224e-02  5.31136276e-01
#  -2.23870405e-01  7.64987903e-01 -3.01076284e-02  1.53335754e+00
#  -3.67891035e-02  3.67071222e-02 -1.67446783e-02  1.33291328e+00
#   7.64987903e-01  1.97062524e-01  1.16587641e+00 -6.78210709e-01
#   2.03446816e+00 -2.03825980e-01  1.21932821e+00 -3.38172817e-03
#   1.28280222e+00  5.97951027e-01  1.67366851e+00  1.06565428e+00
#   1.04560986e+00  1.80061654e+00 -1.28956568e+00  1.34293550e+00
#   3.00256471e-02  3.64099400e-01 -2.37233355e-01 -5.31218258e-01
#  -1.14925470e+00 -7.04936609e-01  5.97951027e-01  9.85476580e-01
#   2.02110521e+00  1.06565428e+00  1.23603189e+00  1.36632066e+00
#  -2.50596305e-01  1.36632066e+00 -5.31218258e-01 -6.84892184e-01
#   1.49995016e+00 -1.12921028e+00 -5.04492357e-01  2.30469899e-01
#  -7.95136522e-01 -3.70862856e-01  1.00552101e+00  7.31580528e-01
#  -8.05158735e-01  8.01736016e-01  7.64987903e-01  1.49995016e+00
#  -1.83781555e-01  5.64543652e-01  1.56676491e+00  9.65432155e-01
#  -1.33670492e-01  9.65432155e-01  6.88150940e-01 -1.00632032e-02
#  -3.04048106e-01  1.46654278e+00  1.13580977e+00 -4.24314657e-01
#   2.02110521e+00  4.77684476e-01  6.98173153e-01  1.70039441e+00
#   2.13469029e+00  1.63357966e+00  6.98173153e-01  1.16587641e+00
#   6.98173153e-01  8.18439704e-01  3.67071222e-02  1.82734244e+00
#   1.86743129e+00  6.31358402e-01 -1.07241774e+00 -4.27655394e-01
#  -5.94692271e-01  8.31802654e-01  2.90603174e-01  5.97951027e-01
#  -2.43914830e-01 -4.44359082e-01 -2.20529668e-01  1.76386842e+00
#   4.30914151e-01  5.24454801e-01  1.92422383e+00 -6.24758909e-01
#  -2.03825980e-01  5.54521439e-01 -1.23611388e+00  3.64099400e-01
#   4.77684476e-01  8.34774476e-02  2.03446816e+00  4.00478597e-02
#   1.63357966e+00  1.01888396e+00  4.44277101e-01  4.17551200e-01
#   1.80358836e-01  9.72113630e-01  6.31358402e-01  3.34032762e-01
#   8.31802654e-01  7.64987903e-01  6.24676927e-01  2.97284649e-01
#   1.06565428e+00  3.70780875e-01 -5.31218258e-01  9.82135843e-01
#   2.36854192e+00  1.94760899e+00  1.03224691e+00  8.98617405e-01
#   5.64543652e-01  1.27946148e+00  1.63655148e-01  5.91269552e-01
#   2.77240224e-01  6.98173153e-01 -4.71084982e-01  7.98395279e-01
#  -1.70418605e-01  2.43535667e+00  1.01888396e+00 -1.07241774e+00
#  -5.98033008e-01  1.63357966e+00 -1.28956568e+00  1.53335754e+00
#   2.03743999e-01  1.06565428e+00 -1.23945461e+00  1.26609853e+00
#   3.97506775e-01  1.11242461e+00 -8.51929060e-01  1.29950591e+00
#   8.71891504e-01  6.98173153e-01  1.61019450e+00  1.61687597e+00
#  -1.44658034e+00  1.09906166e+00  1.71375736e+00 -7.85114310e-01
#  -1.27286199e+00  6.98173153e-01 -1.70418605e-01  4.10869725e-01
#  -2.10507455e-01 -1.78733557e+00  3.34032762e-01 -9.05380861e-01
#  -6.38121859e-01  1.38970582e+00  1.26609853e+00  3.00256471e-02
#  -9.05380861e-01 -1.30626936e+00 -5.71307108e-01  1.16587641e+00
#   1.16587641e+00  1.43313541e+00 -6.71529234e-01  7.51624953e-01
#  -1.17263986e+00 -3.70862856e-01 -1.67077867e-01  9.98122194e-03
#  -1.70418605e-01 -1.27954346e+00  1.92088309e+00 -9.05380861e-01
#   1.49995016e+00 -9.72195612e-01  5.71225127e-01  1.39972803e+00
#   1.33588511e-01  1.49995016e+00 -1.32297305e+00  9.68403977e-02
#  -9.25425286e-01  1.66698704e+00 -9.72195612e-01 -7.71751360e-01
#  -1.08578069e+00  4.30914151e-01 -1.10285329e-01  4.57640051e-01
#  -6.84892184e-01 -9.15403074e-01 -1.00560299e+00  6.58084303e-01
#  -1.15259544e+00  1.11576534e+00  1.16587641e+00 -9.42128974e-01
#   3.00256471e-02 -6.91573659e-01 -9.18743811e-01  4.64321526e-01
#   6.31358402e-01 -9.05380861e-01  1.56676491e+00 -3.70862856e-01
#   1.19928378e+00  1.89415719e+00 -9.92240037e-01  2.36854192e+00
#   3.57417925e-01  1.16587641e+00 -2.03825980e-01 -1.16929913e+00
#  -6.24758909e-01  1.35295771e+00  6.84810203e-01 -7.04936609e-01
#   1.97062524e-01  5.64543652e-01 -3.90907282e-01 -2.53937043e-01
#   4.97728901e-01 -3.38172817e-03  3.60758662e-01 -7.18299559e-01
#   1.63357966e+00 -6.61507021e-01  1.28614296e+00 -7.24981034e-01
#   1.27946148e+00 -1.35972116e+00  1.88413498e+00 -1.21272871e+00
#   9.62091418e-01  1.19928378e+00 -2.03825980e-01  1.63357966e+00
#  -4.37677607e-01 -3.84225806e-01 -6.88232922e-01 -3.10729581e-01
#  -1.70715787e+00 -7.51706935e-01 -5.11173833e-01  1.13246903e+00
#   1.32957255e+00 -7.71751360e-01 -1.34635821e+00  1.37300213e+00
#   3.64099400e-01 -1.18600281e+00 -1.50671362e+00  4.97728901e-01
#  -3.04048106e-01 -8.71973486e-01 -8.21862423e-01  3.00256471e-02
#   6.54743565e-01 -2.37233355e-01  4.64321526e-01 -9.72195612e-01
#  -1.21272871e+00  2.97284649e-01  1.11576534e+00  5.77906602e-01
#   8.65210029e-01 -1.92764654e+00 -1.35972116e+00  5.47839964e-01
#   7.51624953e-01 -1.25949904e+00 -2.34261533e-02 -1.03232889e+00
#  -3.04048106e-01  1.84070539e+00  1.12578756e+00  3.00256471e-02
#  -2.47255568e-01  5.74565864e-01  6.44721352e-01  1.09906166e+00
#  -3.37455481e-01 -4.37677607e-01  6.31358402e-01  7.38262003e-01
#   5.54224257e+00  1.39972803e+00  4.97728901e-01 -1.57055654e-01
#   1.54672049e+00 -1.68377271e+00 -4.37677607e-01 -1.27286199e+00
#   3.27351287e-01  1.16884823e-01 -9.05380861e-01 -9.92240037e-01
#  -6.38121859e-01 -3.37455481e-01 -1.03603854e-01 -4.04270232e-01
#   1.56676491e+00  6.98173153e-01 -1.14591396e+00  3.97506775e-01
#  -4.71084982e-01  2.80580962e-01 -5.17855308e-01 -7.01964787e-02
#  -6.64847759e-01 -6.61507021e-01 -6.78210709e-01  3.33663846e-02
#  -9.55491924e-01  1.49995016e+00 -1.05905479e+00 -4.44359082e-01
#   1.83402391e+00 -9.85558562e-01 -1.47330624e+00 -1.00560299e+00
#   1.09906166e+00 -2.80662943e-01 -1.03603854e-01 -8.71973486e-01
#  -6.71529234e-01 -5.17855308e-01  1.63357966e+00  9.68403977e-02
#   6.71447253e-01 -1.37308411e+00  4.17551200e-01 -1.39981002e+00
#  -1.17263986e+00 -1.27954346e+00  3.00256471e-02  3.64099400e-01
#  -3.84225806e-01 -9.38788236e-01 -1.23648279e-01  1.39972803e+00
#  -7.58388410e-01 -4.04270232e-01 -1.17263986e+00 -5.37899733e-01
#  -1.03603854e-01 -2.03825980e-01 -8.68632748e-01 -1.20307542e-01
#  -1.27286199e+00  7.31580528e-01  1.30247773e-01 -1.02564741e+00
#  -9.45469711e-01 -1.40649149e+00 -1.44323960e+00  1.90083866e+00
#  -1.28288420e+00  1.63655148e-01 -8.58610536e-01 -1.57055654e-01
#  -7.45025460e-01 -1.01228446e+00  4.97728901e-01 -6.71529234e-01
#  -1.01562520e+00 -1.60693574e+00  1.51665385e+00 -1.41651370e+00
#   5.31136276e-01 -5.01151620e-01 -1.13923249e+00  2.90603174e-01
#   2.63877274e-01 -1.03603854e-01 -8.05158735e-01 -3.38172817e-03
#  -9.58832661e-01 -3.77544331e-01 -8.05158735e-01 -1.03603854e-01
#  -1.68043197e+00 -9.85558562e-01 -7.71751360e-01  3.00256471e-02
#   3.10647600e-01 -1.70418605e-01 -1.03232889e+00 -2.10136490e+00
#  -6.98255134e-01 -1.15927691e+00  5.31136276e-01 -1.30329754e-01
#  -1.50671362e+00 -1.55348394e+00 -1.20307542e-01 -5.04492357e-01
#   2.01776448e+00 -7.71751360e-01 -1.29290641e+00  1.29950591e+00
#  -9.22084549e-01 -1.04235110e+00 -3.67891035e-02 -1.70418605e-01
#  -5.71307108e-01 -9.05380861e-01 -1.35303969e+00  5.64543652e-01
#   1.63357966e+00 -7.04936609e-01 -6.88232922e-01 -1.52007657e+00
#  -1.37011229e-01 -3.01076284e-02 -2.70640730e-01 -8.08499473e-01
#   8.31802654e-01 -1.63737130e-01 -1.23945461e+00 -7.91795785e-01
#  -1.11584733e+00 -1.03232889e+00 -6.91573659e-01 -7.04936609e-01
#  -4.37677607e-01 -3.70862856e-01 -1.03566962e+00 -4.04270232e-01
#  -2.08800195e+00  4.00478597e-02 -6.38121859e-01 -1.70418605e-01
#  -4.71084982e-01 -1.40649149e+00 -1.30626936e+00 -9.85558562e-01
#   6.98173153e-01  1.95094973e+00 -7.95136522e-01 -1.24613609e+00
#  -1.06907700e+00 -8.05158735e-01 -7.65069885e-01 -1.67709123e+00
#  -1.23945461e+00  4.33885972e-02 -4.71084982e-01  2.03446816e+00
#  -5.71307108e-01 -1.07241774e+00 -5.71307108e-01 -1.37308411e+00
#  -1.12252880e+00 -5.71307108e-01 -8.71973486e-01 -8.38566110e-01
#  -1.15259544e+00 -7.04936609e-01 -6.91573659e-01 -1.61027648e+00
#  -3.67891035e-02  3.97506775e-01  1.45652057e+00 -4.04270232e-01
#  -3.04048106e-01 -3.38172817e-03 -7.71751360e-01 -1.12252880e+00
#  -8.58610536e-01 -5.04492357e-01 -1.12252880e+00 -1.45994329e+00
#  -1.15259544e+00 -1.09914364e+00  4.30914151e-01 -7.65069885e-01
#  -2.37233355e-01 -1.72052082e+00  2.83921699e-01  1.45652057e+00
#  -7.01964787e-02 -1.03901036e+00 -4.64403507e-01 -8.02186913e-02
#   1.76720916e+00 -1.03901036e+00 -5.04492357e-01 -1.03603854e-01
#  -1.43989887e+00 -1.77100080e-01 -1.29290641e+00 -9.05380861e-01
#  -6.91573659e-01 -1.26283978e+00 -1.62029869e+00  1.45652057e+00
#  -7.75092097e-01 -3.04048106e-01  2.30172717e+00 -2.37233355e-01
#   4.91047426e-01 -8.38566110e-01 -1.17932134e+00  1.45652057e+00
#  -1.58689132e+00 -3.87566544e-01 -6.38121859e-01 -6.35150037e-02
#  -1.28622494e+00 -4.77766457e-01 -6.04714483e-01 -3.90907282e-01
#  -6.51484809e-01 -1.32297305e+00 -2.19824628e+00 -6.71529234e-01
#   1.76720916e+00 -1.50671362e+00 -1.09246216e+00  2.20447686e-01
#   4.57640051e-01 -8.02186913e-02 -1.62698017e+00  1.45652057e+00
#  -3.37455481e-01 -1.58689132e+00 -1.23945461e+00  2.10128291e+00
#  -1.16595839e+00 -9.55491924e-01  1.45652057e+00 -1.39646928e+00
#   1.76720916e+00 -2.30551880e-01 -7.71751360e-01 -1.23945461e+00
#  -1.03901036e+00 -1.09914364e+00 -2.37233355e-01 -9.55491924e-01
#  -1.12252880e+00 -1.03603854e-01 -1.41985444e+00 -9.72195612e-01
#  -8.88677173e-01 -5.98033008e-01  6.44721352e-01  2.30172717e+00
#  -3.70862856e-01  6.44721352e-01 -5.04492357e-01  1.30247773e-01
#   2.30469899e-01 -9.55491924e-01 -6.54825546e-01 -8.38566110e-01
#   4.97728901e-01 -1.32297305e+00 -5.98033008e-01 -1.30626936e+00
#  -6.71529234e-01 -1.41985444e+00 -1.15259544e+00 -7.21640297e-01
#  -9.72195612e-01 -4.77766457e-01 -1.43989887e+00  1.76720916e+00
#  -1.50374179e-01  2.83921699e-01 -1.43321739e+00 -1.57352837e+00
#   1.76720916e+00 -1.31963231e+00 -1.03901036e+00 -6.08055221e-01
#  -1.72052082e+00  4.57640051e-01 -8.28543898e-01 -3.70862856e-01
#  -1.03901036e+00 -1.57352837e+00 -5.71307108e-01 -7.01964787e-02
#  -9.55491924e-01  1.63655148e-01 -1.43321739e+00 -1.39646928e+00
#   1.45652057e+00 -9.05380861e-01 -9.38788236e-01  4.91047426e-01
#  -1.56016542e+00 -6.35150037e-02  1.76720916e+00 -1.45994329e+00
#  -1.07241774e+00  1.45652057e+00 -3.70862856e-01 -1.25949904e+00
#  -3.70862856e-01 -7.01964787e-02 -6.08055221e-01  2.30469899e-01
#  -1.51005435e+00  9.68403977e-02  1.30247773e-01 -8.28543898e-01
#  -3.67891035e-02 -1.11918806e+00  6.44721352e-01 -4.04270232e-01
#  -9.72195612e-01 -2.37233355e-01 -1.50671362e+00]
# [-0.47385755 -0.62727144 -0.01361587 -1.39434089 -0.47385755 -0.3971506
#   0.67674663 -1.01080616  0.06309107  1.06028136 -0.47385755 -0.85739227
#  -0.47385755 -1.16422005  0.06309107 -0.78068533 -1.16422005 -0.55056449
#   0.75345358 -0.93409922  0.75345358 -0.16702977 -0.24373671  0.36991885
#  -1.01080616  0.21650496 -1.01080616 -1.31763395  0.36991885 -1.62446173
#   0.29321191 -0.01361587  0.60003969 -0.93409922  0.29321191  0.52333274
#  -0.47385755  0.52333274 -0.47385755 -0.16702977  0.36991885  1.1369883
#  -1.08751311 -0.55056449 -1.54775478 -0.24373671 -0.09032282 -1.47104784
#  -1.31763395 -0.3971506  -0.16702977 -1.31763395 -1.16422005 -1.31763395
#   0.98357441 -0.24373671 -1.62446173 -1.16422005 -1.01080616 -1.31763395
#  -1.62446173 -0.78068533 -0.09032282  2.13417859  0.36991885 -0.3971506
#  -1.16422005 -0.24373671  0.13979802 -0.55056449 -1.39434089 -1.31763395
#  -1.01080616  0.52333274 -0.16702977 -0.93409922  0.29321191 -0.78068533
#   0.06309107  0.67674663  0.36991885 -0.70397838 -1.08751311 -0.3971506
#  -0.09032282 -0.62727144 -0.55056449 -1.16422005 -0.55056449 -1.08751311
#  -0.93409922 -1.01080616 -1.62446173 -0.78068533 -1.39434089  0.52333274
#  -0.32044366  0.21650496 -0.32044366  0.06309107 -1.16422005 -1.54775478
#  -1.01080616 -0.70397838 -0.3971506  -0.85739227 -0.62727144 -0.78068533
#   1.52052303 -1.240927    0.4466258  -0.16702977 -1.01080616 -1.240927
#  -0.62727144 -0.3971506  -0.47385755  0.83016052 -0.16702977 -0.3971506
#  -0.55056449 -1.31763395 -0.16702977 -1.31763395 -0.32044366 -0.93409922
#  -0.93409922 -1.01080616  0.36991885 -0.93409922 -0.3971506  -0.93409922
#  -0.70397838  0.52333274 -0.89574575 -1.31763395 -1.47104784 -0.24373671
#   1.36710914 -1.240927    1.2904022  -0.47385755  0.60003969 -0.62727144
#   1.44381609 -1.31763395 -0.16702977  0.67674663 -1.16422005 -1.01080616
#  -0.3971506   0.13979802 -0.55056449 -1.77787562 -0.55056449 -0.24373671
#  -0.93409922 -0.70397838 -0.3971506  -1.31763395  0.60003969 -0.09032282
#   1.67393692  0.60003969 -0.93409922 -1.01080616 -0.55056449 -0.16702977
#  -0.3971506  -0.3971506  -0.09032282 -1.47104784 -1.16422005 -1.01080616
#   0.52333274 -1.39434089  0.52333274 -0.93409922 -1.16422005 -0.16702977
#  -0.93409922 -1.01080616 -1.08751311 -0.93409922 -1.47104784 -0.85739227
#  -0.70397838 -1.16422005 -1.54775478 -0.16702977 -0.3971506  -0.93409922
#  -1.08751311 -1.16422005 -0.75511635 -1.01080616 -0.93409922 -0.70397838
#  -0.93409922 -0.93409922 -0.32044366 -0.62727144 -0.93409922 -0.24373671
#  -1.54775478 -0.3971506  -1.16422005 -0.32044366 -0.93409922 -0.93409922
#  -1.31763395 -0.93409922 -0.93409922 -1.47104784 -0.09032282 -0.47385755
#   0.13979802  0.29321191 -0.16702977 -0.19259874  1.36710914 -0.09032282
#  -0.93409922 -1.16422005 -1.240927   -0.32044366 -1.240927   -1.39434089
#   0.06309107 -1.31763395 -0.1158918   0.52333274 -1.16422005  0.83016052
#  -0.55056449 -0.47385755  0.29321191 -0.09032282 -0.01361587 -1.31763395
#   0.52333274 -0.62727144 -1.16422005 -1.01080616 -0.55056449 -0.85739227
#  -1.16422005 -0.85739227  0.868514   -1.31763395 -1.01080616 -0.09032282
#   0.60003969 -1.08751311 -1.01080616 -0.01361587 -1.39434089 -0.85739227
#  -1.16422005 -0.78068533 -1.54775478 -1.240927   -0.78068533 -0.16702977
#  -1.31763395 -0.55056449 -0.55056449 -1.47104784 -1.16422005 -1.31763395
#   0.06309107 -0.55056449  0.13979802 -0.93409922 -1.31763395 -0.93409922
#  -0.78068533 -0.93409922 -0.24373671 -1.01080616 -0.93409922 -1.16422005
#  -1.240927   -0.01361587  0.52333274 -0.47385755  0.52333274 -0.55056449
#  -0.85739227 -1.08751311 -0.85739227 -0.55056449 -1.240927   -1.01080616
#  -0.90853024 -0.78068533 -0.62727144 -0.85739227 -1.01080616 -0.55056449
#  -1.39434089 -0.93409922 -0.93409922 -0.62727144 -0.93409922 -1.240927
#  -0.19259874 -0.16702977 -1.31763395 -1.31763395 -0.24373671 -1.47104784
#  -1.240927   -1.01080616 -0.47385755 -0.93409922 -0.24373671 -0.93409922
#   0.36991885 -1.39434089 -1.08751311 -1.54775478 -1.01080616  1.59722998
#  -0.16702977 -1.01080616  0.98357441 -1.31763395 -0.09032282 -1.16422005
#   0.75345358 -1.31763395 -0.62727144 -0.12867629  0.67674663 -0.70397838
#  -0.78068533 -1.08751311 -1.08751311 -1.31763395  0.83016052 -0.55056449
#  -1.240927    0.67674663  0.98357441 -0.85739227 -0.32044366 -0.55056449
#   0.21650496  1.90405776 -0.09032282  0.52333274  1.06028136 -1.01080616
#  -0.70397838 -0.47385755  1.36710914  0.52333274  0.36991885 -0.78068533
#  -1.39434089 -1.16422005  0.21650496 -0.62727144  1.36710914  0.67674663
#   0.75345358  0.21650496 -0.32044366  1.82735081 -1.47104784  0.52333274
#  -0.85739227  0.36991885 -0.93409922 -1.39434089 -0.47385755 -0.55056449
#   2.05747165 -0.93409922  0.36991885 -1.01080616  1.36710914  0.21650496
#   0.52333274  0.13979802 -0.24373671 -0.55056449  1.52052303  0.56168621
#   2.51771332 -0.24373671  0.98357441 -0.85739227 -0.3971506   0.60003969
#   0.06309107 -0.09032282  0.21650496 -0.55056449 -1.31763395  1.21369525
#  -1.240927   -0.62727144 -1.31763395 -1.31763395 -0.09032282 -1.47104784
#  -1.01080616 -0.85739227 -0.16702977  2.21088554  0.36991885 -0.47385755
#  -0.3971506   1.21369525  0.36991885 -0.24373671 -1.01080616 -0.16702977
#  -1.01080616 -1.16422005  0.36991885 -0.09032282 -1.16422005  0.4466258
#  -0.3971506   0.4466258  -0.55056449  1.21369525 -1.08751311  1.1369883
#  -1.08751311  0.98357441  0.21650496 -0.24373671 -0.70397838 -0.32044366
#  -0.16702977  0.21650496  2.05747165  0.29321191  0.13979802 -1.16422005
#  -1.54775478  1.1369883   1.06028136 -1.16422005 -0.47385755  1.44381609
#   1.1369883  -0.3971506   0.60003969  0.90686747  0.29321191  0.06309107
#  -0.09032282 -0.78068533 -1.08751311  0.52333274  1.59722998 -0.32044366
#  -0.85739227 -0.93409922 -0.16702977  1.90405776  1.52052303 -0.01361587
#  -0.24373671  0.60003969  0.90686747  0.98357441  0.06309107 -1.08751311
#  -0.85739227 -0.32044366 -0.93409922 -1.01080616  0.06309107 -0.93409922
#  -0.16702977 -0.09032282 -0.3971506  -0.93409922 -1.47104784 -1.31763395
#  -0.47385755 -0.3971506  -1.240927    1.59722998  0.13979802  1.44381609
#   0.13979802  0.13979802  0.98357441  1.1369883   1.1369883   0.75345358
#   0.29321191  1.44381609 -1.54775478  0.83016052  1.36710914 -0.55056449
#  -0.24373671  0.21650496  0.21650496  1.1369883   1.21369525  1.1369883
#   1.09863483  1.59722998  0.98357441 -0.85739227  1.59722998  0.60003969
#  -0.93409922  0.29321191  1.36710914  0.36991885 -0.93409922  0.21650496
#  -0.93409922  1.59722998  1.44381609  0.98357441 -1.31763395  0.21650496
#  -0.70397838  1.1369883  -0.16702977  1.52052303  0.4466258   0.52333274
#   1.21369525  0.4466258  -0.01361587  2.55606679 -0.32044366 -1.31763395
#   1.36710914  0.21650496  1.75064387  0.67674663 -0.3971506   0.06309107
#   1.06028136  0.60003969  1.52052303  0.13979802  0.06309107  0.75345358
#   1.75064387  1.59722998  0.90686747 -1.31763395  1.21369525 -0.47385755
#   0.06309107  1.1369883   1.44381609  0.52333274 -0.32044366  0.98357441
#   1.1369883   1.52052303 -1.54775478  1.9807647  -1.08751311  0.13979802
#   1.44381609  0.60003969 -0.70397838 -0.93409922  0.83016052  0.21650496
#   0.60003969  1.06028136  0.67674663 -0.09032282  1.59722998  0.90686747
#   0.13979802  0.21650496 -0.24373671 -0.01361587  0.75345358  2.21088554
#   1.59722998  1.59722998 -0.09032282 -0.01361587  1.67393692  2.28759248
#   0.60003969  0.06309107 -1.47104784  0.52333274  0.98357441 -0.85739227
#   0.90686747  0.29321191  0.52333274  0.98357441  0.4466258   0.13979802
#   0.83016052  0.06309107 -1.39434089  0.42105682  1.44381609  1.9807647
#  -0.16702977 -0.44828857  0.90686747  1.2904022  -0.16702977  0.21650496
#   1.2904022   0.36991885  1.2904022   1.90405776  1.44381609  0.4466258
#   0.98357441 -0.16702977  1.44381609  0.52333274  2.51771332 -0.16702977
#   1.36710914  0.67674663 -0.3971506   1.52052303  0.83016052  0.90686747
#  -0.78068533 -1.47104784  0.29321191  0.67674663  0.67674663  0.83016052
#  -0.01361587  1.59722998  0.90686747 -0.16702977  0.29321191 -1.240927
#   1.1369883   0.13979802  0.98357441  2.13417859  0.83016052  0.36991885
#   0.60003969  0.60003969  1.44381609  1.2904022   1.36710914  1.75064387
#   1.21369525 -0.16702977 -1.47104784  1.21369525  0.4466258   0.13979802
#   0.29321191  1.2904022   0.98357441  1.06028136  1.44381609  2.05747165
#   1.44381609  1.36710914  1.36710914  1.1369883   0.13979802  1.90405776
#   0.60003969 -1.47104784 -0.85739227  0.21650496 -0.24373671 -0.24373671
#  -1.39434089  1.2904022   0.21650496  0.75345358  1.06028136  0.21650496
#   1.75064387  1.52052303  1.36710914  1.44381609  1.82735081 -1.47104784
#   1.21369525 -0.24373671 -1.47104784  0.29321191  0.98357441  0.60003969
#   1.59722998 -1.47104784  1.67393692 -0.24373671  1.36710914  0.75345358
#   1.59722998  1.36710914  0.90686747  0.52333274  0.90686747  0.90686747
#   2.51771332  0.21650496 -1.39434089  1.59722998  0.36991885  0.60003969
#  -0.24373671 -0.24373671  1.90405776 -1.47104784  1.52052303  1.67393692
#   1.44381609 -1.70116867  0.98357441  0.29321191 -1.47104784  2.05747165
#  -1.39434089  1.67393692  1.21369525  1.59722998  1.52052303  1.36710914
#   0.13979802  0.90686747  0.83016052 -0.01361587  1.75064387  1.1369883
#   1.59722998  1.06028136 -0.70397838 -1.47104784 -0.01361587 -0.70397838
#   0.21650496  0.36991885 -0.16702977  0.90686747  1.21369525  1.36710914
#   0.21650496  0.90686747  1.06028136  1.67393692  0.21650496  1.2904022
#   1.44381609  1.59722998  1.1369883   1.36710914  1.06028136 -1.39434089
#   0.60003969 -0.16702977  1.75064387  1.59722998 -1.39434089  1.67393692
#   0.75345358  0.4466258   1.90405776 -0.24373671  1.2904022  -0.01361587
#   0.75345358  1.82735081  0.36991885  0.67674663  0.90686747  1.1369883
#   1.06028136  2.05747165 -1.47104784  1.44381609  1.21369525  0.98357441
#   1.59722998  0.75345358 -1.39434089  2.05747165  0.83016052 -1.47104784
#   1.52052303  0.90686747  1.1369883   0.29321191  0.4466258  -1.47104784
#   1.75064387  0.29321191  0.36991885  1.1369883   0.4466258   1.52052303
#  -0.70397838 -0.01361587  1.2904022  -0.16702977  1.59722998]

# %%
# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(clusters)) - (1 if -1 in clusters else 0)
n_noise_ = list(clusters).count(-1)

print(f'Number of clusters = {n_clusters_}')
print(f'Number of noise sample = {n_noise_}')
# Out:
# Number of clusters = 19
# Number of noise sample = 35
